# %%
import pandas as pd
import numpy as np

df = pd.read_csv('job_descriptions.csv')

# %%
from datetime import datetime, timedelta

# %%
df.head(4)
# Out:
#              Job Id     Experience Qualifications Salary Range    location  \
# 0  1089843540111562  5 to 15 Years         M.Tech    $59K-$99K     Douglas
# 1   398454096642776  2 to 12 Years            BCA   $56K-$116K    Ashgabat
# 2   481640072963533  0 to 12 Years            PhD   $61K-$104K       Macao
# 3   688192671473044  4 to 11 Years            PhD    $65K-$91K  Porto-Novo
#
#             Country  latitude  longitude  Work Type  Company Size  ...  \
# 0       Isle of Man   54.2361    -4.5481     Intern         26801  ...
# 1      Turkmenistan   38.9697    59.5563     Intern        100340  ...
# 2  Macao SAR, China   22.1987   113.5439  Temporary         84525  ...
# 3             Benin    9.3077     2.3158  Full-Time        129896  ...
#
#                  Contact                     Job Title  \
# 0   001-381-930-7517x737  Digital Marketing Specialist
# 1           461-509-4216                 Web Developer
# 2             9687619505            Operations Manager
# ...

# %%
# Function to generate random timestamps between 10 AM to 1 AM (next day)
def generate_random_timestamp():
    start_time = datetime.strptime('10:00', '%H:%M').time()
    end_time = datetime.strptime('01:00', '%H:%M').time()
    
    # Generate a random number of seconds between 0 and the total seconds in a day
    random_seconds = np.random.randint(0, 24*60*60)
    
    # Calculate the timestamp
    timestamp = (datetime.combine(datetime.today(), start_time) + timedelta(seconds=random_seconds)).time()
    
    return timestamp

# Number of rows in your DataFrame
n = len(df)

# %%
# Generate timestamps for each row
timestamps = [generate_random_timestamp() for _ in range(n)]

# Add the 'timestamp' column to the DataFrame
df['timestamp'] = timestamps

# %%
# Step 3: Save the updated DataFrame to a CSV file
df.to_csv('updated_dataset.csv', index=False)

print(f"Updated dataset saved to 'updated_dataset.csv'.")
# Out:
# Updated dataset saved to 'updated_dataset.csv'.
